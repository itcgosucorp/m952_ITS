# %%
import pandas as pd

# %%
df=pd.read_csv("payflow_agg_only_v2_clustered.csv",dtype={"vopenid":"object"})
df
# Out:
#                 vopenid  total_purchase  num_purchase  max_purchase  \
# 0         6210000551702              30             2            15
# 1         6210000801963               2             2             1
# 2         6210000940123               7             1             7
# 3      2210221534402190               7             1             7
# 4      2403281752295297               9             1             9
# ...                 ...             ...           ...           ...
# 12109  2506101346171792               1             1             1
# 12110  2506101545058651               1             1             1
# 12111  2506101735274726               1             1             1
# 12112  2506102001399114               1             1             1
# 12113  2506102031269535               1             1             1
#
#        avg_purchase  count_purchase_on_day  purchase_frequency  \
# 0              15.0                      2                 1.0
# ...

# %%
df['kmeans_labels'].unique()
# Out:
# array([1, 4, 2, 0, 3])
